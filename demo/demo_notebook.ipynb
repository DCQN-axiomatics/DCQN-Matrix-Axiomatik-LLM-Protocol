# %% [markdown]
# # DCQN Live Demonstration Notebook
#
# This interactive notebook demonstrates:
#
# - Real-text verification
# - Axiom-based deterministic reasoning
# - Zero hallucination enforcement
# - Reproducible evaluation across models
# - DOI-anchored machine-logic chains
#
# DCQN.MATRIX = Deterministic • Axiomatic • Reproducible • Zero Hallucination

# %% [markdown]
# ## Demo Workflow
#
# 1. The user provides actual text (PDF upload or pasted sections).
# 2. The model performs Real-Text Verification.
# 3. DCQN extracts deterministic axioms from the provided text.
# 4. DCQN reconstructs the structured reasoning space.
# 5. All protocol stages emit mandatory Machine-State Flags.
# 6. A full DCQN evaluation (E0–E6) is executed.
# 7. Result: PASS / FAIL + a structured audit report.

# %% [markdown]
# ## Example Prompt
#
# Evaluate the following text using **DCQN.MATRIX**:
#
# *"Deterministic models require strict structural boundaries to achieve reproducibility.
# The stability of reasoning chains depends on the underlying axiomatic framework."*
#
# Perform:
# - Real-text verification
# - Axiom extraction
# - Machine-state controlled evaluation
# - Drift detection
# - Neutrality-endpoint analysis

# %% [markdown]
# ## Example LLM Output
#
# Axioms:
# - A1: Deterministic systems require boundaries.
# - A2: Reproducibility emerges from structural stability.
#
# Derived reasoning chain:
# - Divergence: 0
# - Resonance: Stable
# - Coherence: Fully aligned
# - Neutrality endpoint: Reached
#
# **Conclusion:** PASS (No hallucination, no drift, fully text-bound)

# %% [markdown]
# ## Target Audience
#
# - Researchers requiring reproducible scientific reasoning
# - Developers validating deterministic model behavior
# - Cross-model evaluation labs
# - AI safety and alignment researchers
#
# DCQN provides deterministic, reproducible, audit-ready machine logic.

# %%
# DCQN Live Evaluation Demo
from pathlib import Path
from demo_evaluate import evaluate_text

# Load example prompt and output
prompt = Path("example_prompt.txt").read_text()
llm_output = Path("example_llm_output.txt").read_text()

# Run evaluation
report = evaluate_text(prompt, llm_output)
print("DCQN Evaluation Report:", report)
