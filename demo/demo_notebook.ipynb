# %% [markdown]
# # DCQN Demo Notebook
# Deterministic evaluation of an LLM output.

# %%
with open('example_prompt.txt','r',encoding='utf-8') as f:
    prompt = f.read()
print(prompt)

# %%
with open('example_llm_output.txt','r',encoding='utf-8') as f:
    output = f.read()
print(output)

# %%
required = [
    'STATUS_STEP1 = JA_DOI_ZUGRIFF',
    'STATUS_STEP2 = JA_VOLLTEXT_GELESEN'
]
missing = [r for r in required if r not in output]
missing
